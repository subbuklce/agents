# %%
def sum_fun(a, b):
    print(f"printing the sum of two numbers:",a+b)
    return a+b

sum_fun(10,20)

# %% [markdown]
# This below example explains the format specifier clearly

# %%
value=1200000345.6789
print(f"the value in readable format is {value:,.2f}")
